# %%
import matplotlib.pyplot as plt
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/13rdHPzx5B9BuPcRkncDxM5gyK-2VJKbaPhXyAfYusBM/export?format=csv"
df = pd.read_csv(url)

df.head()
# Out:
#    Unnamed: 0    Year      Player Pos   Age   Tm     G    GS      MP   PER  \
# 0           0  1986.0  A.C. Green  PF  22.0  LAL  82.0   1.0  1542.0  11.8
# 1           1  1987.0  A.C. Green  PF  23.0  LAL  79.0  72.0  2240.0  15.7
# 2           2  1988.0  A.C. Green  PF  24.0  LAL  82.0  64.0  2636.0  14.5
# 3           3  1989.0  A.C. Green  PF  25.0  LAL  82.0  82.0  2510.0  17.8
# 4           4  1990.0  A.C. Green  PF  26.0  LAL  82.0  82.0  2709.0  14.7
#
#    ...   BLK    TOV     PF     PTS  height  weight  college    born  \
# 0  ...  49.0   99.0  229.0   521.0   203.0   106.0      NaN  1960.0
# 1  ...  80.0  102.0  171.0   852.0   203.0   106.0      NaN  1960.0
# 2  ...  45.0  120.0  204.0   937.0   203.0   106.0      NaN  1960.0
# 3  ...  55.0  119.0  172.0  1088.0   203.0   106.0      NaN  1960.0
# 4  ...  50.0  116.0  207.0  1061.0   203.0   106.0      NaN  1960.0
#
#    birth_city  birth_state
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24625 entries, 0 to 24624
# Data columns (total 57 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   24625 non-null  int64
#  1   Year         24624 non-null  float64
#  2   Player       24624 non-null  str
#  3   Pos          24624 non-null  str
#  4   Age          24616 non-null  float64
#  5   Tm           24624 non-null  str
#  6   G            24624 non-null  float64
#  7   GS           18233 non-null  float64
#  8   MP           24138 non-null  float64
#  9   PER          24101 non-null  float64
#  10  TS%          24538 non-null  float64
#  11  3PAr         18839 non-null  float64
#  12  FTr          24525 non-null  float64
#  13  ORB%         20792 non-null  float64
#  14  DRB%         20792 non-null  float64
#  15  TRB%         21571 non-null  float64
#  16  AST%         22555 non-null  float64
#  17  STL%         20792 non-null  float64
#  18  BLK%         20792 non-null  float64
#  19  TOV%         19582 non-null  float64
#  20  USG%         19640 non-null  float64
#  21  OWS          24585 non-null  float64
#  22  DWS          24585 non-null  float64
#  23  WS           24585 non-null  float64
#  24  WS/48        24101 non-null  float64
#  25  OBPM         20797 non-null  float64
#  26  DBPM         20797 non-null  float64
#  27  BPM          20797 non-null  float64
#  28  VORP         20797 non-null  float64
#  29  FG           24624 non-null  float64
#  30  FGA          24624 non-null  float64
#  31  FG%          24525 non-null  float64
#  32  3P           18927 non-null  float64
#  33  3PA          18927 non-null  float64
#  34  3P%          15416 non-null  float64
#  35  2P           24624 non-null  float64
#  36  2PA          24624 non-null  float64
#  37  2P%          24496 non-null  float64
#  38  eFG%         24525 non-null  float64
#  39  FT           24624 non-null  float64
#  40  FTA          24624 non-null  float64
#  41  FT%          23766 non-null  float64
#  42  ORB          20797 non-null  float64
#  43  DRB          20797 non-null  float64
#  44  TRB          24312 non-null  float64
#  45  AST          24624 non-null  float64
#  46  STL          20797 non-null  float64
#  47  BLK          20797 non-null  float64
#  48  TOV          19645 non-null  float64
#  49  PF           24624 non-null  float64
#  50  PTS          24624 non-null  float64
#  51  height       24594 non-null  float64
#  52  weight       24621 non-null  float64
#  53  college      22401 non-null  str
#  54  born         24624 non-null  float64
#  55  birth_city   22978 non-null  str
#  56  birth_state  22935 non-null  str
# dtypes: float64(50), int64(1), str(6)
# memory usage: 10.7 MB

# %%
df[["Age", "Year"]].hist()
plt.suptitle("Distribution of Age and Year")
# Out:
# Text(0.5, 0.98, 'Distribution of Age and Year')

# %%
df[["FG", "FGA"]].boxplot()
plt.title("Outlier Detection for FG and FGA")
# Out:
# Text(0.5, 1.0, 'Outlier Detection for FG and FGA')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Year              1
# Player            1
# Pos               1
# Age               9
# Tm                1
# G                 1
# GS             6392
# MP              487
# PER             524
# TS%              87
# 3PAr           5786
# FTr             100
# ORB%           3833
# DRB%           3833
# TRB%           3054
# AST%           2070
# STL%           3833
# BLK%           3833
# TOV%           5043
# USG%           4985
# OWS              40
# DWS              40
# WS               40
# WS/48           524
# OBPM           3828
# DBPM           3828
# BPM            3828
# VORP           3828
# FG                1
# FGA               1
# FG%             100
# 3P             5698
# 3PA            5698
# 3P%            9209
# 2P                1
# 2PA               1
# 2P%             129
# eFG%            100
# FT                1
# FTA               1
# FT%             859
# ORB            3828
# DRB            3828
# TRB             313
# AST               1
# STL            3828
# BLK            3828
# TOV            4980
# PF                1
# PTS               1
# height           31
# weight            4
# college        2224
# born              1
# birth_city     1647
# birth_state    1690
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0          Year           Age             G            GS  \
# count  24625.000000  24624.000000  24616.000000  24624.000000  18233.000000
# mean   12312.000000   1992.594989     26.664405     50.837110     23.593375
# std     7108.769525     17.429594      3.841892     26.496161     28.632387
# min        0.000000   1950.000000     18.000000      1.000000      0.000000
# 25%     6156.000000   1981.000000     24.000000     27.000000      0.000000
# 50%    12312.000000   1996.000000     26.000000     58.000000      8.000000
# 75%    18468.000000   2007.000000     29.000000     75.000000     45.000000
# max    24624.000000   2017.000000     44.000000     88.000000     83.000000
#
#                  MP           PER           TS%          3PAr           FTr  \
# count  24138.000000  24101.000000  2.453800e+04  18839.000000  2.452500e+04
# mean    1209.720317     12.479071  1.870578e+03      0.158604  2.388542e+04
# std      941.146575      6.039014  2.928180e+05      0.187495  3.739704e+06
# min        0.000000    -90.600000  0.000000e+00      0.000000  0.000000e+00
# 25%      340.000000      9.800000  4.580000e-01      0.005000  2.080000e-01
# 50%     1053.000000     12.700000  5.060000e-01      0.064000  2.960000e-01
# 75%     1971.000000     15.600000  5.440000e-01      0.288000  4.000000e-01
# max     3882.000000    129.100000  4.586880e+07      1.000000  5.856548e+08
#
#        ...           TRB           AST           STL           BLK  \
# count  ...  24312.000000  24624.000000  20797.000000  20797.000000
# mean   ...    224.637381    114.852623     39.897052     24.470260
# std    ...    228.190203    135.863913     38.713053     36.935084
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...     51.000000     19.000000      9.000000      3.000000
# 50%    ...    159.000000     68.000000     29.000000     11.000000
# 75%    ...    322.000000    160.000000     60.000000     29.000000
# max    ...   2149.000000   1164.000000    301.000000    456.000000
#
#                 TOV            PF           PTS        height        weight  \
# count  19645.000000  24624.000000  24624.000000  2.459400e+04  2.462100e+04
# mean      73.939832    116.339222    510.116350  5.738784e+05  2.527246e+05
# std       67.713803     84.791873    492.922981  3.399986e+07  1.498073e+07
# min        0.000000      0.000000      0.000000  1.000000e+00  0.000000e+00
# 25%       18.000000     39.000000    106.000000  1.930000e+02  8.600000e+01
# 50%       55.000000    109.000000    364.000000  2.010000e+02  9.500000e+01
# 75%      112.000000    182.000000    778.000000  2.060000e+02  1.040000e+02
# max      464.000000    386.000000   4029.000000  2.015560e+09  8.885660e+08
#
#                born
# count  24624.000000
# mean    1963.689449
# std       17.774212
# min     1913.000000
# 25%     1952.000000
# 50%     1965.000000
# 75%     1978.000000
# max     1997.000000
#
# [8 rows x 51 columns]
